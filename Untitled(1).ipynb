# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
df.iloc[97,2]
# Out:
# "7) For the rest of this Module 1 task, it is up to you to look through the client datasets and identify problems like in the example above with the DOB. We recommend you dot point everything you find in a Word Document before drafting your email. It is also really important that you use the 'Data Quality Framework Table' (you can find this back in the module page in the 'Resources' section). Note that the parameters and criteria provided to you is vague because this is reflective of what happens in the real world. We encourage you to use other sources like Google and Youtube to help you with this task. Even if you're unsure about the quality of your final email, just give it a go, submit the task and you'll get to see model work which is an actual email that a KPMG Data Analyst has submitted!"

# %%
df.iloc[93,2]
# Out:
# "6) Now do you notice anything strange about the data? If you have a look at the first customer (Jephthah Bachmann, you'll notice that they were born in 1843, meaning that they are 175 years old! This is obviously an error in the data so it would be something you'd include in the email to the client."

# %%
df1 = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', 'Transactions')
df1
# Out:
#       Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                         transaction_id
# 1                                                      1
# 2                                                      2
# 3                                                      3
# 4                                                      4
# ...                                                  ...
# 19996                                              19996
# 19997                                              19997
# 19998                                              19998
# 19999                                              19999
# 20000                                              20000
#
#        Unnamed: 1   Unnamed: 2           Unnamed: 3    Unnamed: 4  \
# 0      product_id  customer_id     transaction_date  online_order
# ...

# %%
df2 = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', 'NewCustomerList') 1001
# Out:
#      Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                            first_name
# 1                                               Chickie
# 2                                                 Morly
# 3                                               Ardelis
# 4                                                Lucine
# ...                                                 ...
# 996                                           Ferdinand
# 997                                                Burk
# 998                                            Melloney
# 999                                              Dickie
# 1000                                              Sylas
#
#      Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0     last_name     gender  past_3_years_bike_related_purchases
# ...

# %%
df3 = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', 'CustomerDemographic')
#drop columns from 9 to 25
df3.drop(df.columns[[np.arange(6,26,1)]],inplace=True,axis=1)
df3.loc[df3['Unnamed: 2'].isnull()].count()
#unnamed1>125 Nan Values
#unnamed3>125 Nan Values
#unnamed5>121 Nan Values
df3.loc[(df3['Unnamed: 3']!='Male')&(df3['Unnamed: 3']!='Female')].reset_index(drop=True)
#91 mistakes in gender column instead of male and female there is letters like(F,U,Femal)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py:4307: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
#    Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                         customer_id
# 1                                                   1
# 2                                                  34
# 3                                                  54
# 4                                                  57
# ..                                                ...
# 87                                               3779
# ...

# %%
df4 = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', 'CustomerAddress')
##Drop Unwanted Columns
df4.drop(df.columns[[np.arange(6,26,1)]],inplace=True,axis=1)
df4
##While cleaning data we have some un necessary columns we should delet it from 6 to 25
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py:4307: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
#      Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                           customer_id
# 1                                                     1
# 2                                                     2
# 3                                                     4
# 4                                                     5
# ...                                                 ...
# 3995                                               3999
# ...
